# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 642

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = url + "appid=" + api_key +"&units=" + units + "&q="

# %%
weather_response = requests.get(query_url + cities[2])
weather_response
if weather_response.status_code == 200:
    print("yes")
# Out:
# yes

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrival")

set_count = 1
record_count = 1
weather_data = {"City":[], "Cloudiness":[], "Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed":[]}
for city in cities:
    weather_response = requests.get(query_url + city)
    weather_response_json = weather_response.json()
    
    if weather_response.status_code == 200:
        weather_data["City"].append(city)
        weather_data["Cloudiness"].append(weather_response_json['clouds']['all'])
        weather_data["Country"].append(weather_response_json['sys']['country'])
        weather_data["Date"].append(weather_response_json['dt'])
        weather_data["Humidity"].append(weather_response_json['main']['humidity'])
        weather_data["Lat"].append(weather_response_json['coord']['lat'])
        weather_data["Lng"].append(weather_response_json['coord']['lon'])
        weather_data["Max Temp"].append(weather_response_json['main']['temp_max'])
        weather_data["Wind Speed"].append(weather_response_json['wind']['speed'])
        if record_count <= 50:
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count +=1
        else:
            record_count = 0
            set_count = +1
            print(f"Processing Record {record_count} of set {set_count} | {city}")
            record_count += 1
    else:
        print("City not found. Skipping...")
                  
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrival
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | anadyr
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | meulaboh
# Processing Record 5 of Set 1 | provideniya
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | narsaq
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | san jose de guanipa
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 16 of Set 1 | margate
# Processing Record 17 of Set 1 | college
# Processing Record 18 of Set 1 | kawalu
# Processing Record 19 of Set 1 | richards bay
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | inhambane
# City not found. Skipping...
# Processing Record 22 of Set 1 | baker city
# Processing Record 23 of Set 1 | gravdal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 1 | bridlington
# Processing Record 25 of Set 1 | luderitz
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | ifanadiana
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | madang
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | wenatchee
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | peruibe
# Processing Record 36 of Set 1 | comodoro rivadavia
# Processing Record 37 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 38 of Set 1 | galle
# Processing Record 39 of Set 1 | gat
# Processing Record 40 of Set 1 | bathsheba
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | khandyga
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | sochaczew
# Processing Record 45 of Set 1 | grand-lahou
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | palmer
# Processing Record 50 of Set 1 | sao joao da barra
# Processing Record 0 of set 1 | kirakira
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 3 of Set 1 | seguin
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | dundee
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | faanui
# Processing Record 10 of Set 1 | culpeper
# Processing Record 11 of Set 1 | pereslavl-zalesskiy
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | belyy yar
# Processing Record 14 of Set 1 | jos
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | pringsewu
# Processing Record 17 of Set 1 | albany
# City not found. Skipping...
# Processing Record 18 of Set 1 | saint-philippe
# City not found. Skipping...
# Processing Record 19 of Set 1 | kamenka
# City not found. Skipping...
# Processing Record 20 of Set 1 | jiayuguan
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | ahuimanu
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | atasu
# City not found. Skipping...
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | kushiro
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | yulara
# Processing Record 30 of Set 1 | san quintin
# Processing Record 31 of Set 1 | kruisfontein
# Processing Record 32 of Set 1 | sao filipe
# Processing Record 33 of Set 1 | north bend
# Processing Record 34 of Set 1 | obuasi
# Processing Record 35 of Set 1 | bosaso
# Processing Record 36 of Set 1 | gladstone
# Processing Record 37 of Set 1 | homer
# Processing Record 38 of Set 1 | laem sing
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | shitkino
# Processing Record 41 of Set 1 | osakarovka
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | taoudenni
# Processing Record 45 of Set 1 | hibbing
# Processing Record 46 of Set 1 | karratha
# Processing Record 47 of Set 1 | springfield
# Processing Record 48 of Set 1 | toppenish
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 1 | bandarbeyla
# Processing Record 50 of Set 1 | saint george
# Processing Record 0 of set 1 | sheltozero
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | sharan
# Processing Record 3 of Set 1 | aguimes
# Processing Record 4 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 5 of Set 1 | lorengau
# Processing Record 6 of Set 1 | samarai
# Processing Record 7 of Set 1 | kalispell
# Processing Record 8 of Set 1 | bayan
# Processing Record 9 of Set 1 | midland
# Processing Record 10 of Set 1 | abbeville
# Processing Record 11 of Set 1 | pisco
# Processing Record 12 of Set 1 | pouebo
# Processing Record 13 of Set 1 | avera
# Processing Record 14 of Set 1 | aklavik
# City not found. Skipping...
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | cidreira
# Processing Record 17 of Set 1 | imphal
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | belmonte
# Processing Record 20 of Set 1 | atar
# Processing Record 21 of Set 1 | panaba
# Processing Record 22 of Set 1 | dubbo
# Processing Record 23 of Set 1 | cuauhtemoc
# Processing Record 24 of Set 1 | santiago del estero
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | ardesen
# Processing Record 27 of Set 1 | altamira
# Processing Record 28 of Set 1 | hambantota
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | quatre cocos
# Processing Record 31 of Set 1 | beringovskiy
# Processing Record 32 of Set 1 | eureka
# City not found. Skipping...
# Processing Record 33 of Set 1 | waipawa
# City not found. Skipping...
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | orai
# Processing Record 36 of Set 1 | nabire
# Processing Record 37 of Set 1 | berlevag
# Processing Record 38 of Set 1 | kirkwall
# Processing Record 39 of Set 1 | paita
# Processing Record 40 of Set 1 | green valley
# City not found. Skipping...
# Processing Record 41 of Set 1 | hami
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | codrington
# Processing Record 44 of Set 1 | goderich
# City not found. Skipping...
# Processing Record 45 of Set 1 | bluefields
# Processing Record 46 of Set 1 | flinders
# Processing Record 47 of Set 1 | ardu
# Processing Record 48 of Set 1 | alpena
# Processing Record 49 of Set 1 | sioux lookout
# Processing Record 50 of Set 1 | cockburn town
# Processing Record 0 of set 1 | amapa
# Processing Record 1 of Set 1 | saint-pierre
# Processing Record 2 of Set 1 | fuglebjerg
# Processing Record 3 of Set 1 | ulladulla
# Processing Record 4 of Set 1 | beloha
# Processing Record 5 of Set 1 | isla vista
# Processing Record 6 of Set 1 | lodi
# Processing Record 7 of Set 1 | fortuna
# Processing Record 8 of Set 1 | lethem
# Processing Record 9 of Set 1 | shaowu
# Processing Record 10 of Set 1 | jinka
# Processing Record 11 of Set 1 | bukachacha
# Processing Record 12 of Set 1 | sorong
# Processing Record 13 of Set 1 | atambua
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | husavik
# Processing Record 17 of Set 1 | banda aceh
# Processing Record 18 of Set 1 | aden
# Processing Record 19 of Set 1 | port blair
# Processing Record 20 of Set 1 | sampit
# Processing Record 21 of Set 1 | sarakhs
# Processing Record 22 of Set 1 | iwanai
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | dudinka
# Processing Record 25 of Set 1 | nanortalik
# Processing Record 26 of Set 1 | yumen
# Processing Record 27 of Set 1 | guangshui
# Processing Record 28 of Set 1 | touros
# Processing Record 29 of Set 1 | nisia floresta
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | clyde river
# Processing Record 32 of Set 1 | iracoubo
# Processing Record 33 of Set 1 | altayskoye
# Processing Record 34 of Set 1 | moerai
# Processing Record 35 of Set 1 | vilhena
# Processing Record 36 of Set 1 | cherskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | port-gentil
# Processing Record 38 of Set 1 | pacific grove
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | gotsu
# Processing Record 41 of Set 1 | waynesville
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | tilichiki
# Processing Record 44 of Set 1 | havre-saint-pierre
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | meiganga
# Processing Record 47 of Set 1 | matara
# Processing Record 48 of Set 1 | khash
# Processing Record 49 of Set 1 | faya
# City not found. Skipping...
# Processing Record 50 of Set 1 | leander
# Processing Record 0 of set 1 | erdenet
# Processing Record 1 of Set 1 | nerchinskiy zavod
# Processing Record 2 of Set 1 | kalmunai
# City not found. Skipping...
# Processing Record 3 of Set 1 | loiza
# City not found. Skipping...
# Processing Record 4 of Set 1 | santa cruz del sur
# Processing Record 5 of Set 1 | yelbarga
# Processing Record 6 of Set 1 | san andres
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | kochubey
# Processing Record 9 of Set 1 | toguchin
# City not found. Skipping...
# Processing Record 10 of Set 1 | baraboo
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | broken hill
# Processing Record 13 of Set 1 | manzhouli
# City not found. Skipping...
# Processing Record 14 of Set 1 | neyshabur
# Processing Record 15 of Set 1 | sangin
# Processing Record 16 of Set 1 | mogadishu
# Processing Record 17 of Set 1 | ulaangom
# Processing Record 18 of Set 1 | sur
# Processing Record 19 of Set 1 | samur
# Processing Record 20 of Set 1 | camacha
# Processing Record 21 of Set 1 | haicheng
# Processing Record 22 of Set 1 | kaeo
# Processing Record 23 of Set 1 | pital
# Processing Record 24 of Set 1 | shache
# Processing Record 25 of Set 1 | santa maria
# City not found. Skipping...
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | somerset
# Processing Record 28 of Set 1 | terenos
# Processing Record 29 of Set 1 | shetpe
# Processing Record 30 of Set 1 | amnat charoen
# Processing Record 31 of Set 1 | tevaitoa
# City not found. Skipping...
# Processing Record 32 of Set 1 | krasnaya zarya
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | tiznit
# Processing Record 35 of Set 1 | san jeronimo
# Processing Record 36 of Set 1 | taylorville
# Processing Record 37 of Set 1 | los llanos de aridane
# Processing Record 38 of Set 1 | staryy nadym
# Processing Record 39 of Set 1 | hay river
# Processing Record 40 of Set 1 | ostrovnoy
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | ajdabiya
# Processing Record 43 of Set 1 | lavrentiya
# Processing Record 44 of Set 1 | dutlwe
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | kununurra
# Processing Record 47 of Set 1 | tarata
# Processing Record 48 of Set 1 | omboue
# Processing Record 49 of Set 1 | danielskuil
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 1 | rognan
# Processing Record 0 of set 1 | sarkand
# Processing Record 1 of Set 1 | esperance
# Processing Record 2 of Set 1 | hobyo
# Processing Record 3 of Set 1 | yar-sale
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | lompoc
# Processing Record 6 of Set 1 | novyye lyady
# City not found. Skipping...
# Processing Record 7 of Set 1 | arlit
# Processing Record 8 of Set 1 | spirovo
# City not found. Skipping...
# Processing Record 9 of Set 1 | dunedin
# Processing Record 10 of Set 1 | zyryanka
# Processing Record 11 of Set 1 | ancud
# Processing Record 12 of Set 1 | atikokan
# Processing Record 13 of Set 1 | coachella
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | khrebtovaya
# Processing Record 16 of Set 1 | rorvik
# Processing Record 17 of Set 1 | laguna
# City not found. Skipping...
# Processing Record 18 of Set 1 | pedro juan caballero
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | leningradskiy
# Processing Record 22 of Set 1 | bignona
# Processing Record 23 of Set 1 | shingu
# Processing Record 24 of Set 1 | xining
# Processing Record 25 of Set 1 | erzin
# Processing Record 26 of Set 1 | jumla
# Processing Record 27 of Set 1 | batemans bay
# Processing Record 28 of Set 1 | borujerd
# City not found. Skipping...
# Processing Record 29 of Set 1 | kaniama
# Processing Record 30 of Set 1 | iranshahr
# Processing Record 31 of Set 1 | hirara
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | zabaykalsk
# City not found. Skipping...
# Processing Record 35 of Set 1 | monywa
# Processing Record 36 of Set 1 | byron bay
# City not found. Skipping...
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | gornopravdinsk
# Processing Record 39 of Set 1 | bowen
# Processing Record 40 of Set 1 | salaya
# Processing Record 41 of Set 1 | tigil
# Processing Record 42 of Set 1 | port hardy
# Processing Record 43 of Set 1 | naraina
# Processing Record 44 of Set 1 | saskylakh
# Processing Record 45 of Set 1 | santo angelo
# Processing Record 46 of Set 1 | risor
# Processing Record 47 of Set 1 | victor harbor
# Processing Record 48 of Set 1 | durango
# Processing Record 49 of Set 1 | abha
# Processing Record 50 of Set 1 | tuatapere
# Processing Record 0 of set 1 | solnechnyy
# Processing Record 1 of Set 1 | pandamatenga
# Processing Record 2 of Set 1 | kaka
# Processing Record 3 of Set 1 | adre
# Processing Record 4 of Set 1 | ukiah
# Processing Record 5 of Set 1 | isangel
# Processing Record 6 of Set 1 | fairbanks
# Processing Record 7 of Set 1 | ankang
# Processing Record 8 of Set 1 | hofn
# Processing Record 9 of Set 1 | port-cartier
# Processing Record 10 of Set 1 | mozarlandia
# Processing Record 11 of Set 1 | ilo
# Processing Record 12 of Set 1 | labuhan
# Processing Record 13 of Set 1 | lelystad
# Processing Record 14 of Set 1 | straumen
# Processing Record 15 of Set 1 | nishihara
# Processing Record 16 of Set 1 | noumea
# Processing Record 17 of Set 1 | burnie
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | mitsamiouli
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | filotion
# Processing Record 22 of Set 1 | vangaindrano
# City not found. Skipping...
# Processing Record 23 of Set 1 | mayumba
# Processing Record 24 of Set 1 | ust-tsilma
# Processing Record 25 of Set 1 | sibolga
# Processing Record 26 of Set 1 | odienne
# Processing Record 27 of Set 1 | nha trang
# Processing Record 28 of Set 1 | svetlaya
# Processing Record 29 of Set 1 | naze
# Processing Record 30 of Set 1 | mount isa
# Processing Record 31 of Set 1 | maldonado
# Processing Record 32 of Set 1 | liberal
# Processing Record 33 of Set 1 | nyagan
# Processing Record 34 of Set 1 | pangoa
# Processing Record 35 of Set 1 | tshane
# Processing Record 36 of Set 1 | tarko-sale
# Processing Record 37 of Set 1 | necochea
# Processing Record 38 of Set 1 | longyan
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | vostok
# Processing Record 41 of Set 1 | qianan
# Processing Record 42 of Set 1 | rovaniemi
# Processing Record 43 of Set 1 | enid
# Processing Record 44 of Set 1 | zhezkazgan
# City not found. Skipping...
# Processing Record 45 of Set 1 | todos santos
# Processing Record 46 of Set 1 | kovur
# City not found. Skipping...
# Processing Record 47 of Set 1 | bonavista
# Processing Record 48 of Set 1 | sokoto
# Processing Record 49 of Set 1 | paysandu
# Processing Record 50 of Set 1 | roma
# Processing Record 0 of set 1 | monrovia
# Processing Record 1 of Set 1 | kargopol
# Processing Record 2 of Set 1 | saint-joseph
# Processing Record 3 of Set 1 | vanimo
# Processing Record 4 of Set 1 | pedasi
# Processing Record 5 of Set 1 | vila franca do campo
# Processing Record 6 of Set 1 | braniewo
# Processing Record 7 of Set 1 | tangi
# City not found. Skipping...
# Processing Record 8 of Set 1 | nalut
# Processing Record 9 of Set 1 | sitka
# City not found. Skipping...
# Processing Record 10 of Set 1 | zeya
# Processing Record 11 of Set 1 | piacabucu
# Processing Record 12 of Set 1 | komsomolskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | te anau
# Processing Record 14 of Set 1 | talara
# Processing Record 15 of Set 1 | havoysund
# Processing Record 16 of Set 1 | olinda
# Processing Record 17 of Set 1 | tanout
# Processing Record 18 of Set 1 | hualmay
# Processing Record 19 of Set 1 | camrose
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | pa sang
# Processing Record 22 of Set 1 | pauini
# Processing Record 23 of Set 1 | salalah
# Processing Record 24 of Set 1 | dhidhdhoo
# Processing Record 25 of Set 1 | maralal
# Processing Record 26 of Set 1 | high rock
# Processing Record 27 of Set 1 | baykit
# Processing Record 28 of Set 1 | harlingen
# Processing Record 29 of Set 1 | rome
# Processing Record 30 of Set 1 | half moon bay
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | nemuro
# City not found. Skipping...
# Processing Record 33 of Set 1 | beyneu
# Processing Record 34 of Set 1 | maku
# Processing Record 35 of Set 1 | oktyabrskoye
# Processing Record 36 of Set 1 | saint anthony
# Processing Record 37 of Set 1 | mehamn
# Processing Record 38 of Set 1 | buala
# Processing Record 39 of Set 1 | alta
# Processing Record 40 of Set 1 | caravelas
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | zhanakorgan
# Processing Record 43 of Set 1 | loreto
# Processing Record 44 of Set 1 | eldorado
# Processing Record 45 of Set 1 | akola
# Processing Record 46 of Set 1 | aykhal
# Processing Record 47 of Set 1 | sabang
# Processing Record 48 of Set 1 | salinas
# Processing Record 49 of Set 1 | vardo
# Processing Record 50 of Set 1 | iquitos
# Processing Record 0 of set 1 | ponta delgada
# Processing Record 1 of Set 1 | nyurba
# Processing Record 2 of Set 1 | junqueiropolis
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | olga
# Processing Record 5 of Set 1 | lykhivka

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(weather_data)
weather_df.head()

# %%
weather_df.to_csv('Weather_Data.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Humidity"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("Lat_vs_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], marker="o", alpha=0.75, edgecolor="black")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(0,105)
plt.grid(True)

plt.savefig("Lat_vs_WindSpeed.png")
plt.show()
